# %% [markdown]
# <a href="https://colab.research.google.com/github/justin66744/beats-customer-insights-project/blob/main/Gemini_API_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import google.generativeai as genai
import pandas as pd

df = pd.read_csv('final_dataset.csv')

genai.configure(api_key="AIzaSyCdrzOpWvQivOZkt9MfnbUpDw0VCW_9FnM")

generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-2.5-flash",
  generation_config=generation_config,
)

chat_session = model.start_chat(
  history=[
    {
      "role": "user",
      "parts": [
        "You are a market research analyst specializing in consumer electronics.\\n",
      ],
    }
  ]
)

# %%
response1 = chat_session.send_message("What are the key factors customers consider when buying headphones?")
print(response1.text)
# Out:
# As a market research analyst specializing in consumer electronics, I can tell you that purchasing headphones is far from a simple decision. Customers weigh a complex interplay of factors, often prioritizing differently based on their individual needs, budget, and lifestyle.
#
# Here are the key factors customers consider when buying headphones:
#
# 1.  **Sound Quality:**
#     *   **Audio Fidelity:** Clarity, bass response, treble definition, soundstage, and overall balance. Some prefer a neutral sound, others a more V-shaped (enhanced bass and treble) or bass-heavy profile.
#     *   **Codecs:** For wireless headphones, support for higher-quality Bluetooth codecs like aptX, LDAC, or AAC can be a differentiator for those seeking better audio over Bluetooth.
#     *   **Personal Preference:** What sounds "good" is subjective, so reviews and in-store demos (if available) are crucial.
#
# 2.  **Comfort & Fit:**
#     *   **Form Factor:** Over-ear (circumaural), on-ear (supra-aural), in-ear (earbuds), or true wireless earbuds. Each has distinct comfort profiles.
#     *   **Earcup/Eartip Material:** Breathability, softness, and pressure on the ears (for over/on-ear) or seal and size (for in-ear).
#     *   **Weight & Clamping Force:** Especially for over-ear headphones, a lighter build and balanced clamping force prevent fatigue during long listening sessions.
#     *   **Stability:** For active users (gym, running), headphones need to stay securely in place.
#
# 3.  **Price & Value Proposition:**
#     *   **Budget:** This is often the primary filter. Customers have a range they're willing to spend, from budget-friendly to premium audiophile-grade.
#     *   **Feature-to-Price Ratio:** Is the feature set (ANC, battery life, build quality) commensurate with the price?
#     *   **Brand Perception:** Some brands command a premium due to their reputation for quality, innovation, or status.
#
# 4.  **Features & Technology:**
#     *   **Active Noise Cancellation (ANC):** A major differentiator for commuters, travelers, and office workers seeking to minimize ambient noise.
#     *   **Wireless Connectivity:** Bluetooth version, range, multi-point connection (connecting to two devices simultaneously), and ease of pairing.
#     *   **Battery Life:** For wireless models, how long do they last on a single charge? Fast charging capabilities and charging case capacity are also important.
#     *   **Microphone Quality:** Crucial for calls, video conferencing, and voice assistant interactions.
#     *   **Water/Sweat Resistance (IP Rating):** Essential for fitness enthusiasts or those using headphones outdoors.
#     *   **Transparency/Ambient Mode:** Allows users to hear their surroundings without removing headphones.
#     *   **App Integration:** Custom EQ settings, firmware updates, control customization, and "find my headphones" features.
#     *   **Spatial Audio/3D Audio:** For an immersive listening or gaming experience.
#     *   **Low Latency Mode:** Critical for gaming and watching videos to avoid audio-visual sync issues.
#
# 5.  **Durability & Build Quality:**
#     *   **Materials:** Use of premium materials (metal, high-quality plastics, durable fabrics) vs. flimsy plastics.
#     *   **Construction:** Sturdy hinges, reinforced cables (for wired models), and overall solid feel.
#     *   **Foldability/Portability:** How well do they hold up to being folded and transported?
#     *   **Warranty & Support:** Assurance from the manufacturer.
#
# 6.  **Design & Aesthetics:**
#     *   **Style:** Customers often want headphones that match their personal style – sleek, sporty, professional, minimalist, or vibrant.
#     *   **Color Options:** Availability of different colors.
#     *   **Visibility:** Some prefer inconspicuous earbuds, while others are fine with larger, more noticeable over-ear headphones.
#
# 7.  **Use Case / Lifestyle:**
#     *   **Commuting/Travel:** ANC, portability, long battery life.
#     *   **Work/Office:** Mic quality, comfort for long calls, ANC.
#     *   **Workout/Sports:** Secure fit, sweat resistance, wireless.
#     *   **Gaming:** Low latency, positional audio, clear mic, comfort for extended sessions.
#     *   **Casual Listening at Home:** Primarily sound quality and comfort.
#     *   **Creative/Professional:** Flat frequency response, high impedance (for studio use), wired options.
#
# 8.  **Brand Reputation & Ecosystem:**
#     *   **Trust:** Familiar brands often instill confidence in quality and support.
#     *   **Integration:** For Apple users, AirPods or Beats integrate seamlessly into their ecosystem (quick pairing, automatic switching).
#     *   **Marketing & Hype:** Influencer endorsements and effective marketing can drive demand.
#
# 9.  **Reviews & Recommendations:**
#     *   **Peer Reviews:** Online reviews from other consumers are highly influential.
#     *   **Expert Reviews:** Tech journalists and audiophile sites provide in-depth analysis.
#     *   **Word-of-Mouth:** Recommendations from friends and family.
#
# Ultimately, the weighting of these factors shifts significantly based on the individual customer's primary use case. A professional gamer will prioritize low latency and mic quality, while a frequent flyer will emphasize ANC and battery life, and an audiophile will focus on sound fidelity above all else. Understanding these nuanced priorities is key to effective market segmentation and product development in the headphone market.

# %%
import pandas as pd
import google.generativeai as genai

df = pd.read_csv('final_dataset.csv')

api_key = "AIzaSyCdrzOpWvQivOZkt9MfnbUpDw0VCW_9FnM"

def analyze_reviews(reviews, api_key,prompt_message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text

# %%
unique_products = df['product_name'].unique()
print("Products in dataset:")
for product in unique_products:
    print(f"- {product}")

product_counts = df['product_name'].value_counts()

print("Count of each unique product name:")
print(product_counts)
# Out:
# Products in dataset:
# - 1MORE ComfoBuds Mini Hybrid Active Noise Cancelling Earbuds
# - JBL Tune 230NC TWS - True Wireless In-Ear Headphones
# - JLab Go Air Pop True Wireless Bluetooth Earbuds
# - Beats Studio Buds - True Wireless Noise Cancelling Earbuds
# - Jabra Elite 4 True Wireless Earbuds
# - Sennheiser Consumer Audio CX True Wireless Earbuds
# - Skullcandy Smokin’ Buds Wireless Earbuds
# - Sony WF-C700N Truly Wireless Noise Canceling in-Ear Bluetooth Earbud
# - SHOKZ OpenFit - Open-Ear True Wireless Bluetooth Headphones with Microphone, Earbuds with Earhooks
# - SAMSUNG Galaxy Buds2 Pro True Wireless Bluetooth Earbuds
# Count of each unique product name:
# product_name
# Beats Studio Buds - True Wireless Noise Cancelling Earbuds                                            123
# Sennheiser Consumer Audio CX True Wireless Earbuds                                                    102
# Skullcandy Smokin’ Buds Wireless Earbuds                                                              100
# 1MORE ComfoBuds Mini Hybrid Active Noise Cancelling Earbuds                                           100
# JLab Go Air Pop True Wireless Bluetooth Earbuds                                                       100
# Jabra Elite 4 True Wireless Earbuds                                                                   100
# SHOKZ OpenFit - Open-Ear True Wireless Bluetooth Headphones with Microphone, Earbuds with Earhooks    100
# Sony WF-C700N Truly Wireless Noise Canceling in-Ear Bluetooth Earbud                                   99
# JBL Tune 230NC TWS - True Wireless In-Ear Headphones                                                   98
# SAMSUNG Galaxy Buds2 Pro True Wireless Bluetooth Earbuds                                               90
# Name: count, dtype: int64

# %%
product_mapping = {
    "Beats Studio Buds - True Wireless Noise Cancelling Earbuds": {
        "short_name": "Beats Studio Buds",
        "brand": "Beats"
    },
    "Sennheiser Consumer Audio CX True Wireless Earbuds": {
        "short_name": "Sennheiser Consumer Audio CX True Wireless Earbuds",
        "brand": "Sennheiser"
    },
    "1MORE ComfoBuds Mini Hybrid Active Noise Cancelling Earbuds": {
        "short_name": "1MORE ComfoBuds",
        "brand": "1MORE"
    },
    "Jabra Elite 4 True Wireless Earbuds": {
        "short_name": "Jabra Elite 4",
        "brand": "Jabra"
    },
    "JLab Go Air Pop True Wireless Bluetooth Earbuds": {
        "short_name": "JLab Go Air Earbuds",
        "brand": "JLab"
    },
    "Skullcandy Smokin’ Buds Wireless Earbuds": {
        "short_name": "Skullcandy Smokin’ Buds",
        "brand": "Skullcandy"
    },
    "Sony WF-C700N Truly Wireless Noise Canceling in-Ear Bluetooth Earbud": {
        "short_name": "Sony WF-C700N",
        "brand": "Sony"
    },
    "JBL Tune 230NC TWS - True Wireless In-Ear Headphones": {
        "short_name": "JBL Tune 230NC TWS",
        "brand": "JBL"
    },
    "SAMSUNG Galaxy Buds2 Pro True Wireless Bluetooth Earbuds": {
        "short_name": "SAMSUNG Galaxy Buds2 Pro",
        "brand": "SAMSUNG"
    },
    "SHOKZ OpenFit - Open-Ear True Wireless Bluetooth Headphones with Microphone, Earbuds with Earhooks'": {
        "short_name": "Apple AirPods Pro",
        "brand": "Apple"
    }

}

def clean_product_info(df, mapping):
    df['short_name'] = df['product_name'].map({k: v['short_name'] for k, v in mapping.items()})
    df['brand'] = df['product_name'].map({k: v['brand'] for k, v in mapping.items()})

    df['short_name'] = df['short_name'].fillna(df['product_name'])
    df['brand'] = df['brand'].fillna('Unknown')

    return df

df = clean_product_info(df, product_mapping)

print("\nSample of cleaned data:")
print(df[['product_name', 'short_name', 'brand']].head())
# Out:
# Sample of cleaned data:
#                                         product_name       short_name  brand
# 0  1MORE ComfoBuds Mini Hybrid Active Noise Cance...  1MORE ComfoBuds  1MORE
# 1  1MORE ComfoBuds Mini Hybrid Active Noise Cance...  1MORE ComfoBuds  1MORE
# 2  1MORE ComfoBuds Mini Hybrid Active Noise Cance...  1MORE ComfoBuds  1MORE
# 3  1MORE ComfoBuds Mini Hybrid Active Noise Cance...  1MORE ComfoBuds  1MORE
# 4  1MORE ComfoBuds Mini Hybrid Active Noise Cance...  1MORE ComfoBuds  1MORE

# %%
reviews = df['content'].head(100).tolist()

prompt_message = "Analyze the following reviews and summarize the key insights:"

insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# Here's a summary of the key insights from the reviews of the 1MORE ComfoBuds Mini:
#
# **Key Strengths (Consistently Praised):**
#
# 1.  **Unmatched Tiny Size & Comfort:** This is the overwhelming standout feature. Reviewers consistently praise the "literally half the size," "lightweight," "discreet" nature of the earbuds, making them "almost disappear" in the ear. This makes them exceptionally comfortable, especially for individuals with smaller ears or those who dislike bulky buds.
# 2.  **Ideal for Specific Use Cases (Especially Sleep):** Many found them "incredible for sleeping" due to their flat shape and small size, allowing side-sleepers to use them without discomfort. They are also highly recommended for wearing under helmets (motorcycle, bike) and during light activities like walking or mowing the lawn where other buds might fall out.
# 3.  **Good Sound Quality for Size/Price:** While not audiophile-grade, the sound is generally described as "good," "very good," or "perfectly acceptable," especially considering their minute size and price point. Some found them loud enough and clear, with decent bass after tuning.
# 4.  **Compact & Well-Designed Case:** The charging case is frequently praised for being tiny, pocketable, having a convenient flip-top, and featuring strong magnets to secure the buds.
# 5.  **Decent Active Noise Cancellation (ANC) for Size:** For their small form factor, the ANC is often described as "decent," "good," or "gets the job done." Some users found it effective at blocking low-frequency noises like fans, air conditioners, or even wind (with a dedicated wind reduction mode).
#
# **Key Weaknesses & Problems (Frequent Complaints):**
#
# 1.  **Severe Quality Control (QC) & Durability Issues:** This is by far the most critical and frequently reported problem. Numerous users experienced failures in one or both earbuds within weeks or months. Common issues include:
#     *   Loss of sound/volume (one or both buds becoming significantly quieter).
#     *   Whooshing, roaring, ringing, buzzing, or screeching noises when ANC or Transparency mode is active (often escalating until unusable).
#     *   Earbuds completely losing ANC functionality.
#     *   Reports of multiple units failing, even replacements.
#     *   One user reported the charging case overheating, burning fingers, and melting plastic, raising safety concerns.
#     *   (Note: One reviewer suggested many "QC" issues are actually clogged earwax on the mesh, but many other reports indicate hardware failure despite cleaning.)
# 2.  **Poor App & Equalizer Experience (SoundID):** The proprietary "SoundID" feature is widely disliked. Users often find it makes the sound worse than the default, is cumbersome, and prefer a "real" manual equalizer or common presets, which are missing. The app itself can be unstable, crash, or lack features like multipoint connectivity.
# 3.  **Limited & Inconsistent Touch Controls:** Users complain about the lack of single-tap functionality (though some understand it due to size), and generally limited customization options. Some find the controls unresponsive or that they trigger accidentally.
# 4.  **Subpar Ear Tips:** While multiple sizes are included, several reviewers found the stock ear tips uncomfortable, flimsy, or ineffective for creating a proper seal. The shallow case design also limits compatibility with aftermarket tips.
# 5.  **Connectivity & Software Glitches:** Issues include random disconnections, difficulty switching between devices (lack of multipoint), and earbuds not properly turning off/charging when placed in the case, leading to unexpected battery drain.
#
# **Mixed or Nuanced Points:**
#
# *   **Battery Life:** Considered "good" for the small size (e.g., 4-6 hours with ANC), but often deemed insufficient for a full night's sleep or long-haul listening sessions.
# *   **Call Quality:** Experiences vary widely, from "super clear" to "pretty bad" with dropping audio and tinny sounds.
# *   **Transparency Mode:** Generally functional, but some found it "a little much" or that it amplified certain ambient noises.
# *   **Bass/Volume:** Acceptable for most, but bass-heads might be disappointed, and some wished for higher maximum volume.
#
# **Overall Key Insight:**
#
# The 1MORE ComfoBuds Mini offer a genuinely innovative and highly desirable small form factor, providing exceptional comfort and discreetness for a variety of users, particularly those with small ears or specific needs like sleeping. The initial sound quality and ANC are generally commendable for their size and price. However, this promising foundation is severely undermined by **widespread and persistent quality control and durability issues**, with numerous reports of earbuds failing prematurely in various ways. The software experience, particularly the SoundID EQ and limited controls, also detracts from an otherwise potentially "fantastic" product. While the concept is brilliant, the execution appears to suffer from significant reliability flaws that 1More needs to address for the product to truly live up to its "ComfoBuds" name long-term.

# %%
from textblob import TextBlob

def add_sentiment_info(df):
    df['sentiment_score'] = df['content'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

    df['sentiment_category'] = df['sentiment_score'].apply(lambda x:
        'Positive' if x > 0.1
        else 'Negative' if x < -0.1
        else 'Neutral')

    return df

df = add_sentiment_info(df)

print("\\nSentiment Distribution:")
print(df['sentiment_category'].value_counts()*100/len(df))
# Out:
# \nSentiment Distribution:
# sentiment_category
# Positive    80.632411
# Neutral     17.588933
# Negative     1.778656
# Name: count, dtype: float64

# %%
def analyze_basic_product(reviews, product_name):
    prompt_message = f"""Analyze these reviews for {product_name}:
    1. What are the top 3 most mentioned features?
    2. What do customers love most about this product?
    3. What are the most common complaints?

    Please provide specific examples from the reviews."""


    return analyze_reviews(reviews, api_key, prompt_message)

# %%
product_reviews = df[df['short_name'] == 'Beats Studio Buds']['content'].tolist()[:30]
basic_insights = analyze_basic_product(product_reviews, 'Beats Studio Buds')

# %%
print(basic_insights)
# Out:
# Based on the provided reviews for the Beats Studio Buds:
#
# ---
#
# ### 1. Top 3 Most Mentioned Features:
#
# 1.  **Sound Quality (especially Bass):** This is by far the most consistently mentioned feature, often highlighted positively for its bass-heavy profile.
#     *   **Examples:**
#         *   "Great base." (Review 1)
#         *   "For me- I want it to be great sounding but also noticeably bass heavy. These Beats Studio buds deliver." (Review 2)
#         *   "The sound is very good, just about on par with my IEMs. These are definitely catered towards more bassy genres..." (Review 4)
#         *   "Sound Quality --- Excellent." (Review 5)
#         *   "The mids are nice and clear, and the bass is tight and punchy when the volume is turned up. When listening to the right kind of music at high volumes, they can sound downright amazing." (Review 10)
#
# 2.  **Physical Buttons / Controls:** Many reviewers specifically call out and appreciate the presence of physical "clicky" buttons instead of touch-sensitive controls.
#     *   **Examples:**
#         *   "Very comfortable with the same great physically “clicky” buttons as the Beats Fit Pro." (Review 1)
#         *   "The earbuds HAVE AN ACTUAL BUTTON… which I thought was extinct, I personally hate the sensor buttons because adjusting your earbuds in your ears would trigger the controls." (Review 2)
#         *   "The physical button instead of just touch is an odd choice, but it works." (Review 4)
#         *   "I love the fact that I can connect to music with the press of a button." (Review 13)
#
# 3.  **Noise Cancellation (ANC) & Transparency Mode:** These modes are frequently mentioned, though often with mixed or critical feedback regarding their effectiveness.
#     *   **Examples:**
#         *   "Noise canceling seemed slightly better than average." (Review 1)
#         *   "These have awareness mode, as well as a noise isolation mode." (Review 4)
#         *   "The transparency mode and noise canceling modes were alright. But that’s just it, they’re alright." (Review 8)
#         *   "ANC works well but transparency leaves a lot to be desired." (Review 16)
#         *   "The active noise cancellation feature effectively reduces ambient noise, allowing for an immersive listening experience wherever you are." (Review 17)
#
# ---
#
# ### 2. What Customers Love Most About This Product:
#
# 1.  **Sound Quality (especially Bass):** The robust and bass-heavy sound profile is consistently praised as a major selling point.
#     *   **Examples:**
#         *   "For me- I want it to be great sounding but also noticeably bass heavy. These Beats Studio buds deliver. The company recognizes that your not using these to analyze a song. These are for the people who like bass and want to feel some gravitas in their ears!" (Review 2)
#         *   "The sound is very good, just about on par with my IEMs. These are definitely catered towards more bassy genres, but in the case of metal, I like being able to hear bass along side lead, and provides some heavy kicks." (Review 4)
#         *   "Sound Quality --- Excellent. 5 stars." (Review 5)
#         *   "The sound quality is on par with my old Airpod Pros." (Review 6)
#
# 2.  **Seamless Connectivity (especially with Apple devices):** Many users highlight how easily and quickly these earbuds connect, particularly to iPhones, often comparing it positively to AirPods.
#     *   **Examples:**
#         *   "These connect effortlessly to iPhone, as if they were AirPods. It was the single biggest factor that blew me away with these. They are incredibly easy to connect." (Review 2)
#         *   "You can easily see the battery state on both buds and the case from a pop up window in your apple home screen whenever opening the case, just like AirPods." (Review 2)
#         *   "These things connect seamlessly with my Galaxy s23, and are pretty much rolling by the time you slide them in your ear." (Review 11)
#         *   "Easy to set up and pair and the sound is excellent." (Review 21)
#
# 3.  **Physical Buttons:** The preference for physical buttons over touch controls is a recurring theme among those who appreciate the Beats Studio Buds.
#     *   **Examples:**
#         *   "The feature that really convinced me was the physical buttons, something that I didn’t realize how desperately I needed." (Review 1 - referring to Fit Pro but noting Studio Buds have the same)
#         *   "The earbuds HAVE AN ACTUAL BUTTON… which I thought was extinct, I personally hate the sensor buttons because adjusting your earbuds in your ears would trigger the controls." (Review 2)
#         *   "The physical button instead of just touch is an an odd choice, but it works." (Review 4)
#
# ---
#
# ### 3. Most Common Complaints:
#
# 1.  **Fit / Falling Out (especially during activity or with sweat):** A significant number of users report that the earbuds do not stay securely in their ears, particularly during workouts, sweating, or even simple movements.
#     *   **Examples:**
#         *   "Tested during a workout, a little bit of sweat had these sliding right out of my ear." (Review 1)
#         *   "UPDATE—they have a hard time staying in when working out, and so I had to buy wing tips for these." (Review 2)
#         *   "This may be just my ears, but the small tip is too small, and the medium is just big enough to still be pushed out. The body is very smooth, and if you're someone that produces a lot of earwax (like me), it won't stay put and the only thing keeping it in is the tips, meaning you have to keep pushing them back in, and bumping the button." (Review 4)
#         *   "If you need something to work out in, live in a hot environment and are cleaning your yard. Nope. Not staying in." (Review 5)
#         *   "They fall out of my ears if i do simple things like turn my head or chew. i can barely walk or exercise with them in because they just fall out." (Review 6)
#
# 2.  **Noise Cancellation (ANC) & Transparency Mode Effectiveness:** While these features are present, many reviewers find them underwhelming or subpar compared to expectations or competitors.
#     *   **Examples:**
#         *   "The noise canceling was solid, but nothing special." (Review 1)
#         *   "The noise cancellation doesn’t entirely work, but i dont really mind too much since it still blocks out some noise just not entirely." (Review 3)
#         *   "Noise cancellation is a joke, it sounds the same as when its on transparent mode or off." (Review 6)
#         *   "The transparency mode and noise canceling modes were alright. But that’s just it, they’re alright. Granted, the AirPod Pros have a higher price tag, so they do the ANC and Transparency mode much better." (Review 8)
#         *   "Transparency mode, which should let you hear your surroundings, instead adds a hollow reverb and doesn't work well; I couldn’t even hear someone talking directly to me while using it. Noise cancellation mode introduces a persistent noise layer, similar to wind or the sea, rather than effectively blocking external sounds." (Review 10)
#
# 3.  **Case Quality and Functionality:** Multiple reviewers express dissatisfaction with the physical build quality, design, or battery life of the charging case.
#     *   **Examples:**
#         *   "The case for these earbuds also was the flimsiest of any I had tested, with a very weak hinge that I was scared of breaking off within the 2 weeks of using." (Review 1)
#         *   "And the cases battery is pretty short lived… only lasts two days generally" (Review 2)
#         *   "By default, the case doesn't have a loop for a string to hold on to and the case is very smooth, so you have to buy a third party case and put it over the stock case just to make it easier to hold on to." (Review 4)
#         *   "The case feels like cheap plastic. i got a silicone case because i was afraid of scratching it up." (Review 6)
#         *   "Also, was not a fan of how the case just doesn’t have that 'premium' feel." (Review 8)

# %%
def analyze_sentiment_patterns(reviews, sentiment_category, product_name):
    prompt_message = f"""Analyze these {sentiment_category.lower()} reviews for {product_name}:
    1. What specific aspects create {sentiment_category.lower()} reactions?
    2. Identify common phrases or descriptions used
    3. Note any comparisons with competitor products
    4. Find unexpected or unique feedback

    Support your analysis with specific examples."""

    return analyze_reviews(reviews, api_key, prompt_message)

positive_reviews = df[
    (df['short_name'] == 'Beats Studio Buds') &
    (df['sentiment_category'] == 'Positive')
]['content'].tolist()[:30]

positive_insights = analyze_sentiment_patterns(
    positive_reviews,
    'Positive',
    'Beats Studio Buds'
)
print(positive_insights)
# Out:
# Based on the provided positive reviews for Beats Studio Buds, here's a detailed analysis:
#
# ---
#
# ### Analysis of Positive Reviews for Beats Studio Buds
#
# **1. What specific aspects create positive reactions?**
#
# The positive reactions to Beats Studio Buds stem from several key aspects, often highlighted in comparison to other earbuds:
#
# *   **Sound Quality (especially Bass):** This is a consistently praised feature. Reviewers love the "great bass" and "punch" that makes music enjoyable, particularly for genres benefiting from a strong low end.
#     *   *Examples:* "These Buds deliver. The company recognizes that your not using these to analyze a song. These are for the people who like bass and want to feel some gravitas in their ears!" and "The sound is very good... definitely catered towards more bassy genres... provides some heavy kicks." Another noted, "The sound has some solid bass which is helpful for the gym... the bass is nice and strong."
# *   **Physical Buttons:** A significant and recurring positive is the inclusion of actual, "clicky" physical buttons instead of touch sensors. This provides tactile feedback and prevents accidental presses.
#     *   *Examples:* "Same great physically 'clicky' buttons as the Beats Fit Pro... No need to guess if you tapped them once or twice, you will know." Another reviewer exclaimed, "The earbuds HAVE AN ACTUAL BUTTON… which I thought was extinct, I personally hate the sensor buttons because adjusting your earbuds in your ears would trigger the controls."
# *   **Comfort & Fit (for general use):** Many users find the Studio Buds comfortable for extended wear, particularly with the right ear tips.
#     *   *Examples:* "Very comfortable," "The buds fit nice for me with the small ear tips, not uncomfortable," and "They fit snuggly in your ears well enough that they do not fall off when running and working out. Although adjustments might need to be made to them occasionally."
# *   **Seamless Connectivity & Apple Ecosystem Integration:** For iPhone users, the ease of pairing and features like battery status pop-ups (akin to AirPods) are highly valued. There's also positive feedback for Android connectivity.
#     *   *Examples:* "These connect effortlessly to iPhone, as if they were AirPods. It was the single biggest factor that blew me away with these." Another praised, "These things connect seamlessly with my Galaxy s23, and are pretty much rolling by the time you slide them in your ear."
# *   **Noise Cancellation (ANC):** While not universally described as "best-in-class," the ANC is generally seen as effective and contributes positively to the listening experience, often described as "solid" or "good."
#     *   *Examples:* "Noise canceling seemed slightly better than average," "Noise cancellation doesn’t entirely work, but i dont really mind too much since it still blocks out some noise just not entirely," and "The ANC works well." One user even noted, "There are times I use these with no music playing and you can barely hear your wife."
# *   **Value for Money:** Especially when purchased on sale or as refurbished, reviewers frequently feel they get a high-quality product for a reasonable price.
#     *   *Examples:* "They feel definitely worth the price and a all around great buy." and "These are 100% worth the $75 I spent on them, but NO WAY ARE THEY WORTH THE $150 RETAIL PRICE TAG." Also, "If you're on a budget get them. The fits, not on sale and on sale, not for a budget audio buyer."
# *   **Appearance & Design:** The "classic look" and range of vibrant colors are appealing to users, as is their small, discreet size.
#     *   *Examples:* "Classic look," "The color of the beats are great. i got red and it looks super cool," "Appearance wise they are really small, if you have long hair you could easily hide these," and "The pink color is exactly like the picture, and the buds themselves are comfortable and lightweight."
# *   **Battery Life & Charging:** Reviewers appreciate that the battery "lasts all day" and that the charging is quick.
#     *   *Examples:* "The battery lasts me all day, what more do you want?" and "Battery life --- Excellent. 5 stars."
#
# **2. Identify common phrases or descriptions used**
#
# Several phrases and descriptive terms appear repeatedly across the reviews, indicating widely shared perceptions:
#
# *   "**Great bass**" / "**bass heavy**" / "punch" / "gravitas"
# *   "**Physical buttons**" / "**clicky buttons**" / "**actual button**" (often contrasted with hated "sensor buttons")
# *   "**Connects like AirPods**" / "**seamless connectivity**" / "effortless to iPhone"
# *   "**Very comfortable**" / "**snug fit**" (often with a caveat about active use)
# *   "**Worth the price**" / "**good value**" / "affordable" / "good bang for the buck"
# *   "**Noise cancelling is good**" / "solid" / "better than average" (sometimes with a note that it's not perfect)
# *   "**Lightweight**"
# *   "**Small**" / "discreet"
# *   "**Lasts all day**" / "long battery life"
# *   "**Clear sound**" / "great sound quality"
#
# **3. Note any comparisons with competitor products**
#
# Reviewers frequently benchmark the Beats Studio Buds against several competitors:
#
# *   **Beats Fit Pro:**
#     *   Studio Buds are noted as "very comfortable" while Fit Pro's wingtip is "not the most comfortable."
#     *   Both share the desirable "physical 'clicky' buttons."
#     *   Fit Pro is highlighted as better for workouts due to its wingtip, while Studio Buds can slide out with sweat.
#     *   The sound quality of the Fit Pro is described as a "huge difference in quality" (implying better) than the Studio Buds, but the Studio Buds are "super affordable" in comparison.
# *   **Apple AirPods (Pro):**
#     *   **Connectivity/Integration:** Studio Buds connect "effortlessly to iPhone, as if they were AirPods" and show battery status via a "pop up window in your apple home screen whenever opening the case, just like AirPods." One reviewer stated, "This is basically an AirPod at a lesser price."
#     *   **Sound:** Studio Buds are praised for delivering bass that AirPods (and others) lack, which can sound "very flat" to some users. Sound quality is described as "on par with my old AirPod Pros."
#     *   **ANC/Transparency:** AirPod Pros are noted to have better ANC and Transparency modes due to their higher price tag.
#     *   **Fit/Durability:** For some, Studio Buds "stay in my ears more than my air pods do when I am moving around a lot."
#     *   **Features:** AirPod Pros have wireless charging, which Studio Buds lack. Studio Buds are compatible with Apple's "Find My app."
# *   **Samsung Galaxy Buds (Pro/Live):**
#     *   **Sound:** Studio Buds are preferred by users who like bass over the "balanced" audio of Galaxy Buds (and AirPods/Raycons), which can sound "very flat."
#     *   **Fit:** Galaxy Buds Pro also "didn’t stay in during a workout," similar to the Studio Buds for some users.
#     *   **Connectivity:** Studio Buds connect "seamlessly with my Galaxy s23," indicating strong cross-platform performance.
# *   **Raycon E55:**
#     *   Studio Buds deliver the "excessive bass" and "manual button" features that Raycons used to offer before they "put sensors on the earbuds in the place of buttons and Balanced out the audio."
#     *   Fit is "not as good as the raycon E55 but only by a little bit."
# *   **Bose QuietComfort:**
#     *   Bose's noise canceling is described as "unmatched," suggesting Studio Buds, while good, don't reach that level.
#     *   Bose is noted as "the most expensive pair of earbuds by a longshot."
# *   **IEMs (In-Ear Monitors):**
#     *   One reviewer considered the sound "just about on par with my IEMs," indicating high praise for audio quality.
# *   **Jabra 75t:**
#     *   Compared to Jabra's "amazing hear-through" and functional app, Studio Buds "don’t do any one thing particularly well," but are still considered a "solid enough product."
#
# **4. Find unexpected or unique feedback**
#
# Beyond the standard praise, some reviewers offered surprisingly unique or unexpected insights:
#
# *   **Extreme Durability (Water and Heat):**
#     *   "She dropped one into the sink and they were soaked and stopped working for a few days I riced them and blowdried them and they came back to life. Still sound as good as ever."
#     *   "Upside to that, these bad boys have survived my washer and dryer three times so far with no hit to the existing quality of sound or performance."
#     *   "I accidentally dropped one of my earpieces in a hot oven... I let it cool a bit... and they work perfectly. I can’t even tell that I accidentally baked in of them."
#     These examples showcase an extraordinary level of accidental robustness not typically highlighted for earbuds.
# *   **Apple Warranty for Refurbished Products:** "I would recommend purchasing used ear buds at the reduced price since Apple will honor warranty and repair or replace, which Amazon will not do, but will only refund purchase price." This is valuable information for potential buyers considering refurbished options.
# *   **Specific Volume Fix:** One reviewer provided a detailed workaround for an initial low volume issue: "go into the setting for your headphones and change the press and hold feature to change the volume, after you use the headphones to turn the volume up, you can switch that setting off back to noise control." This suggests a specific user experience hurdle and a community-driven solution.
# *   **Interchangeable Ears:** "Unlike other beats these headphones are interchangeable (at least for me). I was able to swap ears which is nice." This is not a commonly advertised feature and offers an unexpected benefit for some users.
# *   **"Earbuds Need to Update?":** A reviewer's frustration, "why do my earbuds need to update?!" highlights a common modern tech annoyance, even for seemingly simple devices.
# *   **Transparency Mode in Comparison:** While a con, the description of Samsung Galaxy Buds Pro's *noise amplification* ("surrounding sound was actually louder and clearer than it would be without the earbuds in") is a unique competitor feature that stands out, even if the Studio Buds don't have it.
# *   **Case Flimsiness:** One reviewer's strong critique of the case's quality was quite specific: "the case for these earbuds also was the flimsiest of any I had tested, with a very weak hinge that I was scared of breaking off within the 2 weeks of using." This detailed negative feedback is specific and highlights a potential weak point for the overall product experience.

# %%
def analyze_comparative_reviews(reviews_dict):
    products_list = ", ".join(reviews_dict.keys())

    prompt_message = f"""Compare customer feedback across these products: {products_list}

    For each product, analyze:
    1. Standout features and unique selling points
    2. Common complaints or limitations
    3. Price-to-value perception
    4. Target user preferences

    Then compare:
    1. Key differences in customer satisfaction
    2. Feature preferences across products
    3. Quality and reliability mentions

    Format as a structured comparison with specific examples."""

    combined_reviews = []
    for product, reviews in reviews_dict.items():
        labeled_reviews = [f"[{product}] {review}" for review in reviews]
        combined_reviews.extend(labeled_reviews[:20])

    return analyze_reviews(combined_reviews, api_key, prompt_message)

# %%
products_to_compare = ['Beats Studio Buds', 'SAMSUNG Galaxy Buds2 Pro']
reviews_dict = {}
for product in products_to_compare:
    reviews = df[df['short_name'] == product]['content'].tolist()[:20]
    reviews_dict[product] = reviews

comparison_insights = analyze_comparative_reviews(reviews_dict)
print(comparison_insights)
# Out:
# Based on the provided customer feedback, here's a structured comparison of the Beats Studio Buds and SAMSUNG Galaxy Buds2 Pro:
#
# ---
#
# ## Product Analysis
#
# ### Beats Studio Buds
#
# **1. Standout Features and Unique Selling Points**
# *   **Bass-Heavy Sound Profile:** Many users highlight the strong, punchy bass, making them ideal for genres where gravitas is desired. As one user stated, "The company recognizes that your not using these to analyze a song. These are for the people who like bass and want to feel some gravitas in their ears!" Another noted, "The sound is very good... definitely catered towards more bassy genres."
# *   **Physical "Clicky" Buttons:** A significant advantage for many users who dislike touch-sensitive controls. Reviewers praised the "physical 'clicky' buttons" for providing clear feedback and avoiding accidental presses during adjustments.
# *   **Seamless Apple Connectivity:** Despite being Beats, they connect "effortlessly to iPhone, as if they were AirPods," including a pop-up window for battery status.
# *   **Comfort (for many):** Often described as "very comfortable," "fit nice for me," and even for those with sensitive ears, "didn't have any pain while wearing these."
# *   **Affordable (especially on sale):** Frequently perceived as a great value when purchased on discount, with one user stating, "These are 100% worth the $75 I spent on them."
#
# **2. Common Complaints or Limitations**
# *   **Poor Fit During Activity/Sweat:** This is the most consistent complaint. Users repeatedly report them "sliding right out of my ear" with "a little bit of sweat," or "fall out of my ears if i do simple things like turn my head or chew." Many needed to buy wingtips or found them unsuitable for workouts.
# *   **Mediocre Noise Cancellation & Transparency:** NC is often described as "solid, but nothing special," "slightly better than average," "doesn't entirely work," "more noise reducing," or even "a joke" and "adds a persistent noise layer." Transparency mode is similarly deemed "alright" or ineffective.
# *   **Flimsy/Cheap Case:** The case is widely criticized as "flimsiest of any I had tested," with a "very weak hinge." Other mentions include "cheap plastic," "doesn't have that 'premium' feel," and no loop for a string.
# *   **Subpar Microphone Quality:** Several users reported that "microphone quality lacks" and "mic isn't too good," with one stating it "sounds horrible and robotic on a PC, making it unusable for video conferencing."
# *   **Inconsistent Connectivity & Battery Life:** Some users reported difficulties connecting, random disconnections, and short case battery life (e.g., "only lasts two days generally").
#
# **3. Price-to-Value Perception**
# *   **Excellent Value on Sale:** The overwhelming sentiment is that these earbuds are "definitely worth the price" and a "great buy" when purchased for around $75-$100. At this price point, they are seen as "on par with earbuds in the 200$ range."
# *   **Poor Value at Full Price:** Conversely, many users feel they are "NO WAY ARE THEY WORTH THE $150 RETAIL PRICE TAG" and can be "disappointing at best" if full price is paid.
#
# **4. Target User Preferences**
# *   Individuals who prioritize strong, punchy bass in their audio.
# *   Users who strongly prefer physical buttons over touch controls to avoid accidental presses.
# *   iPhone users seeking AirPods-like connectivity with a different sound profile and aesthetic.
# *   Those looking for comfortable earbuds for casual listening, especially if they are not prone to heavy sweating or intense workouts.
# *   Budget-conscious buyers looking for good sound and features, primarily when the product is on sale.
#
# ### SAMSUNG Galaxy Buds2 Pro
#
# **1. Standout Features and Unique Selling Points**
# *   **Exceptional Sound Quality:** Consistently praised for delivering "amazing sound quality," "crisp, clear and balanced," with "deep bass and clear highs." Many reviewers highlight the clarity and richness of the audio.
# *   **Effective Active Noise Cancellation (ANC):** A major highlight, described as "mind-blowing," "top-notch," "works wonderfully," and "great noise cancelation."
# *   **Comfort and Secure Fit (for many):** Numerous users found them "very comfortable," "fit perfectly in my ear," and "stay there during workouts." They accommodate various ear sizes, including "tiny ear canals" and those with "many piercings" by swapping tips.
# *   **Samsung Ecosystem Integration:** Provides "a lot of different settings" and features via the Samsung Wear app, including "awesome" ambient sensors that activate when speaking, making them ideal for Samsung phone users.
# *   **Noise Amplification/Enhanced Transparency:** A unique feature allowing surrounding sound to be "actually louder and clearer than it would be without the earbuds in," beneficial for hard of hearing individuals or situational awareness.
# *   **Sleek, Compact Design with Matte Finish:** Appreciated for its "clean and slick design," "smaller," and a "grippier, matte texture for the box too," which is deemed "vastly superior and more premium than the first Pro."
#
# **2. Common Complaints or Limitations**
# *   **Inconsistent Fit for *Some* Users:** While many praise the fit, a notable subset reported issues such as "hard time getting these to fit snug in my ears," "silicon ear tips easily slide out," or "didn't stay in during a workout."
# *   **Variable Transparency Mode Performance:** While some found the noise amplification unique and useful, others called the passthrough audio "garbage," describing it as "listening to the world through a ton garbage pail."
# *   **Signal Drop Issues:** One user reported "signal drops off heavily" if the phone is even slightly elevated or not at the same height.
# *   **Lack of Simultaneous Multi-Device Connectivity:** A significant limitation for users who need to connect to two devices at once, as they "can't do this" and require manual switching.
# *   **Case Durability:** The case "feels a little cheap and doesn't feel very durable" according to some feedback.
# *   **Touch Control Sensitivity:** Can be "very annoying if you have long hair" as brushing the earbuds can pause music or trigger controls.
# *   **Battery Life (for some):** One long-term user noted "very short battery life" after two years, though others reported "impressive" or "lasts long."
#
# **3. Price-to-Value Perception**
# *   **Good Value on Sale:** Similar to Beats, the value is highlighted when purchased on sale (e.g., $100 on Prime Day), where they are considered "above average ear buds."
# *   **Questionable Value at Full Price:** Many users stated they are "definitely not worth $150+" and suggest considering Sony earbuds at that price point, especially for bass lovers.
#
# **4. Target User Preferences**
# *   Samsung Galaxy phone users looking for deep integration and advanced features through the Wear app.
# *   Individuals prioritizing superior Active Noise Cancellation.
# *   Users who appreciate a balanced yet rich sound profile with strong bass.
# *   Active individuals who need earbuds that generally stay securely in place during workouts.
# *   Those interested in unique features like noise amplification for situational awareness.
# *   Users who prefer a sleek, compact, and modern design.
#
# ---
#
# ## Comparative Analysis
#
# **1. Key Differences in Customer Satisfaction**
# *   **Fit During Activity:** This is a major differentiator. The **Galaxy Buds2 Pro** generally receives higher satisfaction for staying in during workouts and physical activity ("stays there during workouts," "don't fall out even when running"). The **Beats Studio Buds**, however, are a consistent source of frustration, with numerous complaints about them "sliding right out of my ear" or "falling out" with sweat or movement.
# *   **ANC Performance:** The **Galaxy Buds2 Pro** enjoys significantly higher satisfaction for its ANC, described as "mind-blowing" and "top-notch." The **Beats Studio Buds** ANC is consistently rated as "alright," "noise reducing," or even "a joke," leading to lower satisfaction for users prioritizing strong noise cancellation.
# *   **Case Quality:** The **Beats Studio Buds** case is a common point of dissatisfaction, frequently called "flimsy" and "cheap plastic." The **Galaxy Buds2 Pro** case, while some found it "a little cheap," is generally perceived as better due to its "grippier, matte texture."
# *   **Control Method:** **Beats Studio Buds** users highly praise the physical "clicky" buttons for their reliability and avoiding accidental triggers, leading to higher satisfaction for those who dislike touch controls. **Galaxy Buds2 Pro** uses touch controls, which are functional for most but cause frustration for some due to sensitivity (e.g., with long hair).
# *   **Sound Profile Preference:** The **Beats Studio Buds** cater more specifically to a bass-heavy sound profile, satisfying users who prioritize "gravitas" in their audio. The **Galaxy Buds2 Pro** offers a more balanced sound that is also described as having strong bass, appealing to a broader audience while still delivering punch.
#
# **2. Feature Preferences Across Products**
# *   **Sound Signature:** Users who explicitly desire a **bass-forward, punchy sound** without being audiophiles will lean towards the **Beats Studio Buds**. Those seeking **exceptional overall sound quality that is balanced but still has strong bass** would prefer the **Galaxy Buds2 Pro**.
# *   **Controls:** A strong preference for **physical, tactile buttons** over touch controls is a clear driver towards the **Beats Studio Buds**. Users who are comfortable with **touch controls** and the ability to customize them via an app would find the **Galaxy Buds2 Pro** suitable.
# *   **Active Noise Cancellation:** For **superior, highly effective ANC**, the **Galaxy Buds2 Pro** is the preferred choice. Users for whom ANC is a secondary or less critical feature, or who are on a budget, might tolerate the **Beats Studio Buds**' weaker performance.
# *   **Ecosystem Integration:** **Beats Studio Buds** are preferred by **iPhone users** seeking AirPods-like connectivity and ease of use. **Galaxy Buds2 Pro** are strongly preferred by **Samsung Galaxy phone users** for seamless integration and app-driven customization.
# *   **Workout/Activity Use:** Users needing earbuds that reliably **stay in during workouts and with sweat** will find the **Galaxy Buds2 Pro** generally more reliable. Those prioritizing lightweight comfort for *less active* use might still prefer the **Beats Studio Buds**, but often need external wingtips for activity.
# *   **Ambient Sound/Transparency:** The **Galaxy Buds2 Pro** offers a more advanced "noise amplification" feature, appealing to those who want to actively hear their surroundings or have slight hearing deficits. The **Beats Studio Buds**' transparency mode is generally less effective.
#
# **3. Quality and Reliability Mentions**
# *   **Durability (Buds):** The **Beats Studio Buds** show surprising durability in some isolated incidents, with one user reporting them surviving multiple washer/dryer cycles and a sink dunk. However, there were also mentions of speaker malfunctioning after a couple of months, requiring warranty repair. The **Galaxy Buds2 Pro** are noted as being "very sensitive" to falls.
# *   **Case Durability:** This is

# %%
def analyze_feature(reviews, feature_name):
    prompt_message = f"""Analyze mentions of {feature_name} in these reviews:
    1. How do customers describe the {feature_name}?
    2. What specific aspects are praised or criticized?
    3. How does {feature_name} compare across products?
    4. What improvements do customers suggest?

    Include specific quotes and examples."""

    return analyze_reviews(reviews, api_key, prompt_message)

# %%
battery_reviews = df[
    df['content'].str.contains('battery|charge|power', case=False, na=False)
]['content'].tolist()[:40]

battery_insights = analyze_feature(battery_reviews, "battery life")
print(battery_insights)
# Out:
# The reviews discuss battery life primarily for two distinct products: the **1More ComfoBuds Mini** and a **JBL earbud model (likely the JBL Wave Beam or similar, referred to as JBL 230 NC or just "JBL" in reviews)**, along with comparisons to several other brands. There's a clear divergence in customer experience and sentiment regarding battery life between these two main products.
#
# ### 1. How do customers describe the battery life?
#
# **For 1More ComfoBuds Mini:**
# Customers describe the battery life as **mixed to predominantly negative**, often calling it "low," "not great," or "decent" at best, especially when considering ANC usage. There's an acknowledgement that its small size might contribute to this.
#
# *   "The battery life seems low at a 4 hour play time with ANC enabled..."
# *   "These aren't marketed as sleep headphones, and I suspect that is partly because of the battery life. They last around 4 hours with ANC enabled..."
# *   "No they're not top sound quality top noise canceling, top battery life. They are good everywhere." (implies not a strong suit)
# *   "Sound quality is fine and battery life is decent." (one neutral assessment)
# *   "The battery life is not great."
# *   "From a technical perspective battery life, sound quality, and reliability were my major issues."
# *   "As compared to Samsung galaxy pro, the sound quality is significantly less as is the range and battery life."
#
# **For JBL Earbuds:**
# Customers describe the battery life as **overwhelmingly positive and exceptional**. Phrases like "so fricken long," "superb," "amazing," and lasting for "days" or "all day" are common.
#
# *   "The charge life is so fricken long I can go a week without charging it and it still has life. I've had these for about a month and only charged them maybe twice."
# *   "Battery - 5/5: ...if the battery matches up or comes close to their claims... then I will be impressed. My other buds max out at around 8 hours, so getting almost 4x the total battery life is excellent. 8 hours without recharging is very impressive." (This particular review seems to be for a JBL model with higher stated battery life, possibly an error in the snippet or a different JBL model).
# *   "These are amazing in both categories [quality and battery life]."
# *   "These things really get me through the day with their ambient sound control, great sound quality and omg talk about battery life!"
# *   "Battery life is amazing and even more the crystal-clear sound is better than other expensives earbuds."
# *   "Battery life superb..."
# *   "Best sound and when fully charged they last approximately 5 days."
# *   "They normally last me all day at work."
#
# ### 2. What specific aspects are praised or criticized?
#
# **Praised:**
#
# *   **Quick Charging (1More):** "They do charge quickly, at least."
# *   **Decent for Size (1More):** "For being so small... great battery life for the size." "The smaller size does mean the battery is smaller but I usually don’t keep them in for more than 1 hour at a time."
# *   **Exceptional Longevity (JBL):** The primary praise for JBL, often citing "a week without charging" or "5 days" of use with the case. "I can go a week without charging it and it still has life."
# *   **Ability to Use One Earbud (JBL):** "you can listen to each bud independently which is a must for people like me that usually only wear one. So In the off chance one dies you just pop in the other one and your good to go for another 8 hours." This extends perceived battery life.
# *   **Holds Charge When Not in Use (JBL):** "kept them outside of the case, and come back to them a month later, and they are still at the same battery percentage as a month ago - unbelievable."
#
# **Criticized:**
#
# *   **Short Play Time (1More):** Often cited as "4 hours with ANC enabled," which is not enough for specific use cases. "They last around 4 hours with ANC enabled, so they won't last you a full night's sleep."
# *   **Inadequate for Specific Use Cases (1More):** "Not huge deal for me since my neighbors usually cool it with the music at around 4am, but it wouldn't be ideal if you were trying to block out a snoring partner, loud AC unit, etc." Also, "I knew the batteries lasted less than 8 hours with anc on but personally think 8 hours needs to be the target to get you through long haul flights."
# *   **Charging/Connection Issues (1More & JBL):** Earbuds failing to turn off in the case, leading to battery drain. "The vast majority of the time they would reconnect while not in use and drain the battery/not charge." For JBL: "When I woke up this morning I went to use the left one & the app said it only had 20% battery even though it was in the charger all night. In messing with them I realized even in the case the left was still connected & playing."
# *   **Battery Degradation/Failure (1More & JBL):** This is a significant criticism across both brands, indicating poor long-term reliability.
#     *   **1More:** "my 3rd pair died in less than a year... 3rd pair just bought on sale and again in 6 months right ear is broken, makes a loud squealing noise and then nothing." And, "After about two months the maximum volume on one of the buds started to diminish... After another month the volume was so low as to make the left earbud worthless."
#     *   **JBL:** "About a month ago my right earbud started having connectivity issues... and now has completely lost the ability to gain charge." "Unfortunately a little over one year just is not long enough of a life cycle for $99 earbuds. My left ear bud won't hold a charge longer than 20 minutes and it heats up like crazy when it's in the charging case." "after four or five months, the right headphone dies after about an hour and a half full volume."
# *   **Volume Decline with Low Battery (1More):** "Interestingly both earbuds will decline in volume as the battery gets lower."
# *   **Case Malfunction (1More):** "The case didn't work... it seems there's a problem with the case and I couldn't charge them."
#
# ### 3. How does battery life compare across products?
#
# There's a significant split between the 1More ComfoBuds Mini and the JBL earbuds, and then further comparisons to high-end brands.
#
# **1More ComfoBuds Mini:**
# *   **Lower than other owned earbuds:** "significantly less than all of the other wireless earbuds I've owned."
# *   **Inferior to Samsung Galaxy Buds Pro:** "As compared to Samsung galaxy pro, the sound quality is significantly less as is the range and battery life."
# *   **Specific comparison to other small earbuds:** In one review, for "Battery life of earbuds without case," the 1More ComfoBuds Mini ranked second (2) out of three, behind "Life A2 NC (by far)" and ahead of "Airpods Pro."
# *   **Objectively lower than top-tier ANC earbuds:** One reviewer states the JBL 230 NC has "about four hours" battery life (similar to 1More's stated 4 hours with ANC), while comparing it to "Sony WF-1000XM5... up to eight hours with noise cancellation on, and up to 24 hours with the charging case" and "Apple AirPods Pro 2... up to six hours with noise cancellation on, and up to 30 hours with the charging case." This places the 1More significantly below these premium options in terms of per-charge earbud life.
#
# **JBL Earbuds:**
# *   **Superior to Bose (for one user):** "I was looking for some backup earphones in case the Bose I have run out of battery, to my surprise." This implies the Bose has less reliable or shorter battery life than the JBL for this user.
# *   **Strong overall performance:** While one technical review cites ~4 hours per bud (similar to 1More), other user experiences strongly suggest excellent *total* battery life with the case, lasting "days." "My other buds max out at around 8 hours, so getting almost 4x the total battery life is excellent. 8 hours without recharging is very impressive." (This specific 8-hour claim might be for a different JBL model or refers to total playback with the case, as another JBL review says 4 hours per bud.)
# *   **Better than Raycons and Skullcandy Sesh Evo:** Two reviewers switched from these brands to JBL and found JBL's battery life to be superior. "The charge life is so fricken long I can go a week without charging it and it still has life. I've had these for about a month and only charged them maybe twice." (vs Raycons). "These are very comparable with the higher end jlab buds that will last me the entire work day and have enough juice in the case so that I'm not having to charge them multiple times a week." (vs Jlab).
#
# ### 4. What improvements do customers suggest?
#
# *   **Extended Play Time:** Particularly for scenarios like sleeping or long flights. "They last around 4 hours with ANC enabled, so they won't last you a full night's sleep." A target of "8 hours needs to be the target to get you through long haul flights."
# *   **Improved Reliability and Longevity:** This is a major area for improvement across both brands. Customers are frustrated by earbuds dying or degrading within months to a year. "I would sacrifice some of the audio quality and battery life if they could just make them last." "I really needed these to last me longer than 5 months."
# *   **Fix Charging/Connection Issues:** The problem of earbuds draining battery in the case or not charging consistently needs to be addressed. "Unlike basically any other earbud, putting the earbuds in the case and closing it does not seem to be an 'off switch.'"
# *   **Consistent Performance as Battery Drains:** Avoid performance degradation like diminishing volume as the battery gets low. "Interestingly both earbuds will decline in volume as the battery gets lower."
# *   **Address Safety Concerns:** One reviewer reported their JBL case "was so hot that I burned my fingers... It had melted the plastic around the charge port and even destroyed my charging cord," indicating a critical safety issue related to charging.

# %%
df.to_csv('final_dataset.csv', index=False)
